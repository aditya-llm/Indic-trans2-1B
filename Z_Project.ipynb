# %% [markdown]
# <a href="https://colab.research.google.com/github/aditya-llm/Indic-trans2-1B/blob/main/Z_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install IndicTransToolkit
# Out:
# Collecting IndicTransToolkit
#   Downloading indictranstoolkit-1.1.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: cython in /usr/local/lib/python3.12/dist-packages (from IndicTransToolkit) (3.0.12)
# Collecting sacremoses (from IndicTransToolkit)
#   Downloading sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from IndicTransToolkit) (4.56.1)
# Collecting sacrebleu (from IndicTransToolkit)
#   Downloading sacrebleu-2.5.1-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 2.7 MB/s eta 0:00:00
# Collecting indic-nlp-library-itt (from IndicTransToolkit)
#   Downloading indic_nlp_library_itt-0.1.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting morfessor (from indic-nlp-library-itt->IndicTransToolkit)
#   Downloading Morfessor-2.0.6-py3-none-any.whl.metadata (628 bytes)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from indic-nlp-library-itt->IndicTransToolkit) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from indic-nlp-library-itt->IndicTransToolkit) (2.2.2)
# Collecting sphinx-argparse (from indic-nlp-library-itt->IndicTransToolkit)
#   Downloading sphinx_argparse-0.5.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting sphinx-rtd-theme (from indic-nlp-library-itt->IndicTransToolkit)
#   Downloading sphinx_rtd_theme-3.0.2-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting portalocker (from sacrebleu->IndicTransToolkit)
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from sacrebleu->IndicTransToolkit) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.12/dist-packages (from sacrebleu->IndicTransToolkit) (0.9.0)
# Collecting colorama (from sacrebleu->IndicTransToolkit)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from sacrebleu->IndicTransToolkit) (5.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from sacremoses->IndicTransToolkit) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from sacremoses->IndicTransToolkit) (1.5.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from sacremoses->IndicTransToolkit) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers->IndicTransToolkit) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers->IndicTransToolkit) (0.35.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers->IndicTransToolkit) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers->IndicTransToolkit) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers->IndicTransToolkit) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->IndicTransToolkit) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers->IndicTransToolkit) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers->IndicTransToolkit) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers->IndicTransToolkit) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers->IndicTransToolkit) (1.1.10)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->indic-nlp-library-itt->IndicTransToolkit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->indic-nlp-library-itt->IndicTransToolkit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->indic-nlp-library-itt->IndicTransToolkit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->IndicTransToolkit) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->IndicTransToolkit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->IndicTransToolkit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->IndicTransToolkit) (2025.8.3)
# Requirement already satisfied: sphinx>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from sphinx-argparse->indic-nlp-library-itt->IndicTransToolkit) (8.2.3)
# Requirement already satisfied: docutils>=0.19 in /usr/local/lib/python3.12/dist-packages (from sphinx-argparse->indic-nlp-library-itt->IndicTransToolkit) (0.21.2)
# Collecting sphinxcontrib-jquery<5,>=4 (from sphinx-rtd-theme->indic-nlp-library-itt->IndicTransToolkit)
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->indic-nlp-library-itt->IndicTransToolkit) (1.17.0)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->IndicTransToolkit) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->IndicTransToolkit) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->IndicTransToolkit) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->IndicTransToolkit) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->IndicTransToolkit) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->IndicTransToolkit) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->IndicTransToolkit) (3.1.6)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->IndicTransToolkit) (2.19.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->IndicTransToolkit) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->IndicTransToolkit) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->IndicTransToolkit) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->IndicTransToolkit) (1.4.1)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->IndicTransToolkit) (3.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from Jinja2>=3.1->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->IndicTransToolkit) (3.0.2)
# Downloading indictranstoolkit-1.1.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (546 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 546.3/546.3 kB 24.1 MB/s eta 0:00:00
# Downloading indic_nlp_library_itt-0.1.1-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 2.0 MB/s eta 0:00:00
# Downloading sacrebleu-2.5.1-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 3.3 MB/s eta 0:00:00
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 20.1 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Downloading sphinx_argparse-0.5.2-py3-none-any.whl (12 kB)
# Downloading sphinx_rtd_theme-3.0.2-py2.py3-none-any.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 36.0 MB/s eta 0:00:00
# Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 8.2 MB/s eta 0:00:00
# Installing collected packages: morfessor, sacremoses, portalocker, colorama, sacrebleu, sphinxcontrib-jquery, sphinx-argparse, sphinx-rtd-theme, indic-nlp-library-itt, IndicTransToolkit
# Successfully installed IndicTransToolkit-1.1.1 colorama-0.4.6 indic-nlp-library-itt-0.1.1 morfessor-2.0.6 portalocker-3.2.0 sacrebleu-2.5.1 sacremoses-0.1.1 sphinx-argparse-0.5.2 sphinx-rtd-theme-3.0.2 sphinxcontrib-jquery-4.1

# %%
import sys
import torch
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, BitsAndBytesConfig
from transformers.utils import is_flash_attn_2_available, is_flash_attn_greater_or_equal_2_10
from IndicTransToolkit.processor import IndicProcessor

# %%
from nltk import sent_tokenize
from indicnlp.tokenize.sentence_tokenize import sentence_split, DELIM_PAT_NO_DANDA

# %%
# !pip install mosestokenizer
# Out:
# Collecting mosestokenizer
#   Downloading mosestokenizer-1.2.1.tar.gz (37 kB)
#   Preparing metadata (setup.py) ... done
# Collecting docopt (from mosestokenizer)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting openfile (from mosestokenizer)
#   Downloading openfile-0.0.7-py3-none-any.whl.metadata (1.7 kB)
# Collecting uctools (from mosestokenizer)
#   Downloading uctools-1.3.0.tar.gz (4.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting toolwrapper (from mosestokenizer)
#   Downloading toolwrapper-2.1.0.tar.gz (3.2 kB)
#   Preparing metadata (setup.py) ... done
# Downloading openfile-0.0.7-py3-none-any.whl (2.4 kB)
# Building wheels for collected packages: mosestokenizer, docopt, toolwrapper, uctools
#   Building wheel for mosestokenizer (setup.py) ... done
#   Created wheel for mosestokenizer: filename=mosestokenizer-1.2.1-py3-none-any.whl size=49172 sha256=75cec5b0f984d23a5441608b0abf4119a9a857af9e9f0e2fff65efe102b0857b
#   Stored in directory: /root/.cache/pip/wheels/c0/58/3c/907b853d08a202a2ca29004b6d5b5d94013cc2c51720482b2c
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=7f2b9245fcc1dfbb6470a08cc40a40cfdac58aca6be63527b8724dab7c2ab03b
#   Stored in directory: /root/.cache/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
#   Building wheel for toolwrapper (setup.py) ... done
#   Created wheel for toolwrapper: filename=toolwrapper-2.1.0-py3-none-any.whl size=3337 sha256=d6311a0814928b7fa4ca5a7072d051c01403906578cd17339f4f7df3a2cb774e
#   Stored in directory: /root/.cache/pip/wheels/ef/cb/9a/e20737af0cf23e07c863ec9e8dcfdbb6c973f9fa4375cb9f6b
#   Building wheel for uctools (setup.py) ... done
#   Created wheel for uctools: filename=uctools-1.3.0-py3-none-any.whl size=6147 sha256=07b2dc5051fbdf4f809f5c22c306cc11d98d4008ffd24cc793ab71122b680436
#   Stored in directory: /root/.cache/pip/wheels/45/81/1c/3e44305f05ac7148345e2b753c3e4696ed0c2afdd05305d68d
# Successfully built mosestokenizer docopt toolwrapper uctools
# Installing collected packages: toolwrapper, openfile, docopt, uctools, mosestokenizer
# Successfully installed docopt-0.6.2 mosestokenizer-1.2.1 openfile-0.0.7 toolwrapper-2.1.0 uctools-1.3.0

# %%
from mosestokenizer import MosesSentenceSplitter

# %%
en_indic_ckpt_dir = "ai4bharat/indictrans2-en-indic-1B"  # ai4bharat/indictrans2-en-indic-dist-200M
indic_en_ckpt_dir = "ai4bharat/indictrans2-indic-en-1B"  # ai4bharat/indictrans2-indic-en-dist-200M
indic_indic_ckpt_dir = (
    "ai4bharat/indictrans2-indic-indic-dist-320M"  # ai4bharat/indictrans2-indic-indic-dist-320M
)
BATCH_SIZE = 4
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

if len(sys.argv) > 1:
    quantization = sys.argv[1]
    attn_implementation = sys.argv[2]
else:
    quantization = ""
    attn_implementation = "eager"

# %%
# FLORES language code mapping to 2 letter ISO language code for compatibility
# with Indic NLP Library (https://github.com/anoopkunchukuttan/indic_nlp_library)
flores_codes = {
    "asm_Beng": "as",
    "awa_Deva": "hi",
    "ben_Beng": "bn",
    "bho_Deva": "hi",
    "brx_Deva": "hi",
    "doi_Deva": "hi",
    "eng_Latn": "en",
    "gom_Deva": "kK",
    "guj_Gujr": "gu",
    "hin_Deva": "hi",
    "hne_Deva": "hi",
    "kan_Knda": "kn",
    "kas_Arab": "ur",
    "kas_Deva": "hi",
    "kha_Latn": "en",
    "lus_Latn": "en",
    "mag_Deva": "hi",
    "mai_Deva": "hi",
    "mal_Mlym": "ml",
    "mar_Deva": "mr",
    "mni_Beng": "bn",
    "mni_Mtei": "hi",
    "npi_Deva": "ne",
    "ory_Orya": "or",
    "pan_Guru": "pa",
    "san_Deva": "hi",
    "sat_Olck": "or",
    "snd_Arab": "ur",
    "snd_Deva": "hi",
    "tam_Taml": "ta",
    "tel_Telu": "te",
    "urd_Arab": "ur",
}

# %%
def split_sentences(input_text, lang):
    if lang == "eng_Latn":
        input_sentences = sent_tokenize(input_text)
        with MosesSentenceSplitter(flores_codes[lang]) as splitter:
            sents_moses = splitter([input_text])
        sents_nltk = sent_tokenize(input_text)
        if len(sents_nltk) < len(sents_moses):
            input_sentences = sents_nltk
        else:
            input_sentences = sents_moses
        input_sentences = [sent.replace("\xad", "") for sent in input_sentences]
    else:
        input_sentences = sentence_split(
            input_text, lang=flores_codes[lang], delim_pat=DELIM_PAT_NO_DANDA
        )
    return input_sentences

# %%
def initialize_model_and_tokenizer(ckpt_dir, quantization, attn_implementation):
    if quantization == "4-bit":
        qconfig = BitsAndBytesConfig(
            load_in_4bit=True,
            bnb_4bit_use_double_quant=True,
            bnb_4bit_compute_dtype=torch.bfloat16,
        )
    elif quantization == "8-bit":
        qconfig = BitsAndBytesConfig(
            load_in_8bit=True,
            bnb_8bit_use_double_quant=True,
            bnb_8bit_compute_dtype=torch.bfloat16,
        )
    else:
        qconfig = None

    if attn_implementation == "flash_attention_2":
        if is_flash_attn_2_available() and is_flash_attn_greater_or_equal_2_10():
            attn_implementation = "flash_attention_2"
        else:
            attn_implementation = "eager"

    tokenizer = AutoTokenizer.from_pretrained(ckpt_dir, trust_remote_code=True)
    model = AutoModelForSeq2SeqLM.from_pretrained(
        ckpt_dir,
        trust_remote_code=True,
        attn_implementation=attn_implementation,
        low_cpu_mem_usage=True,
        quantization_config=qconfig,
    )

    if qconfig == None:
        model = model.to(DEVICE)
        model.half()

    model.eval()

    return tokenizer, model

# %%
def batch_translate(input_sentences, src_lang, tgt_lang, model, tokenizer, ip):
    translations = []
    for i in range(0, len(input_sentences), BATCH_SIZE):
        batch = input_sentences[i : i + BATCH_SIZE]

        # Preprocess the batch and extract entity mappings
        batch = ip.preprocess_batch(batch, src_lang=src_lang, tgt_lang=tgt_lang)

        # Tokenize the batch and generate input encodings
        inputs = tokenizer(
            batch,
            truncation=True,
            padding="longest",
            return_tensors="pt",
            return_attention_mask=True,
        ).to(DEVICE)

        # Generate translations using the model
        with torch.no_grad():
            generated_tokens = model.generate(
                **inputs,
                use_cache=True,
                min_length=0,
                max_length=256,
                num_beams=5,
                num_return_sequences=1,
            )

        # Decode the generated tokens into text
        generated_tokens = tokenizer.batch_decode(
            generated_tokens,
            skip_special_tokens=True,
            clean_up_tokenization_spaces=True,
        )

        # Postprocess the translations, including entity replacement
        translations += ip.postprocess_batch(generated_tokens, lang=tgt_lang)

        del inputs
        torch.cuda.empty_cache()

    return translations

# %%
def translate_paragraph(input_text, src_lang, tgt_lang, model, tokenizer, ip):
    input_sentences = split_sentences(input_text, src_lang)
    translated_text = batch_translate(input_sentences, src_lang, tgt_lang, model, tokenizer, ip)
    return " ".join(translated_text)


ip = IndicProcessor(inference=True)

en_indic_tokenizer, en_indic_model = initialize_model_and_tokenizer(
    en_indic_ckpt_dir, quantization, attn_implementation
)

indic_en_tokenizer, indic_en_model = initialize_model_and_tokenizer(
    indic_en_ckpt_dir, quantization, attn_implementation
)

indic_indic_tokenizer, indic_indic_model = initialize_model_and_tokenizer(
    indic_indic_ckpt_dir, quantization, attn_implementation
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenization_indictrans.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-en-indic-1B:
# - tokenization_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# dict.SRC.json: 0.00B [00:00, ?B/s]
# dict.TGT.json: 0.00B [00:00, ?B/s]
# model.SRC:   0%|          | 0.00/759k [00:00<?, ?B/s]
# model.TGT:   0%|          | 0.00/3.26M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/96.0 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# configuration_indictrans.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-en-indic-1B:
# - configuration_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_indictrans.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-en-indic-1B:
# - modeling_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors:   0%|          | 0.00/4.46G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/163 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenization_indictrans.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-indic-en-1B:
# - tokenization_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# dict.SRC.json: 0.00B [00:00, ?B/s]
# dict.TGT.json: 0.00B [00:00, ?B/s]
# model.SRC:   0%|          | 0.00/3.26M [00:00<?, ?B/s]
# model.TGT:   0%|          | 0.00/759k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/96.0 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# configuration_indictrans.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-indic-en-1B:
# - configuration_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_indictrans.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-indic-en-1B:
# - modeling_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors:   0%|          | 0.00/4.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/163 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenization_indictrans.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-indic-indic-dist-320M:
# - tokenization_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# dict.SRC.json: 0.00B [00:00, ?B/s]
# dict.TGT.json: 0.00B [00:00, ?B/s]
# model.SRC:   0%|          | 0.00/3.26M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/96.0 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# configuration_indictrans.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-indic-indic-dist-320M:
# - configuration_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_indictrans.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-indic-indic-dist-320M:
# - modeling_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors:   0%|          | 0.00/1.28G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/168 [00:00<?, ?B/s]

# %%
# ---------------------------------------------------------------------------
#                              Hindi to English
# ---------------------------------------------------------------------------
hi_sents = [
    "जब मैं छोटा था, मैं हर रोज़ पार्क जाता था।",
    "उसके पास बहुत सारी पुरानी किताबें हैं, जिन्हें उसने अपने दादा-परदादा से विरासत में पाया।",
    "मुझे समझ में नहीं आ रहा कि मैं अपनी समस्या का समाधान कैसे ढूंढूं।",
    "वह बहुत मेहनती और समझदार है, इसलिए उसे सभी अच्छे मार्क्स मिले।",
    "हमने पिछले सप्ताह एक नई फिल्म देखी जो कि बहुत प्रेरणादायक थी।",
    "अगर तुम मुझे उस समय पास मिलते, तो हम बाहर खाना खाने चलते।",
    "वह अपनी दीदी के साथ बाजार गयी थी ताकि वह नई साड़ी खरीद सके।",
    "राज ने मुझसे कहा कि वह अगले महीने अपनी नानी के घर जा रहा है।",
    "सभी बच्चे पार्टी में मज़ा कर रहे थे और खूब सारी मिठाइयाँ खा रहे थे।",
    "मेरे मित्र ने मुझे उसके जन्मदिन की पार्टी में बुलाया है, और मैं उसे एक तोहफा दूंगा।",
]
src_lang, tgt_lang = "hin_Deva", "eng_Latn"
en_translations = batch_translate(
    hi_sents, src_lang, tgt_lang, indic_en_model, indic_en_tokenizer, ip
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2947123802.py in <cell line: 0>()
#      15 ]
#      16 src_lang, tgt_lang = "hin_Deva", "eng_Latn"
# ---> 17 en_translations = batch_translate(
#      18     hi_sents, src_lang, tgt_lang, indic_en_model, indic_en_tokenizer, ip
#      19 )
#
# /tmp/ipython-input-1932986653.py in batch_translate(input_sentences, src_lang, tgt_lang, model, tokenizer, ip)
#      18         # Generate translations using the model
#      19         with torch.no_grad():
# ---> 20             generated_tokens = model.generate(
#      21                 **inputs,
#      22                 use_cache=True,
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
#     122     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2549         elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2550             # 11. run beam sample
# -> 2551             result = self._beam_search(
#    2552                 input_ids,
#    2553                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in _beam_search(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, **model_kwargs)
#    3348             model_inputs.update({"output_hidden_states": output_hidden_states} if output_hidden_states else {})
#    3349
# -> 3350             model_outputs = self(**model_inputs, return_dict=True)
#    3351
#    3352             # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# ~/.cache/huggingface/modules/transformers_modules/ai4bharat/indictrans2-indic-en-1B/ac3daf0ecd37be3b6957764a9179ab2b07fa9d6a/modeling_indictrans.py in forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1716                 )
#    1717
# -> 1718         outputs = self.model(
#    1719             input_ids,
#    1720             attention_mask=attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# ~/.cache/huggingface/modules/transformers_modules/ai4bharat/indictrans2-indic-en-1B/ac3daf0ecd37be3b6957764a9179ab2b07fa9d6a/modeling_indictrans.py in forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1612
#    1613         # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_attn)
# -> 1614         decoder_outputs = self.decoder(
#    1615             input_ids=decoder_input_ids,
#    1616             attention_mask=decoder_attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# ~/.cache/huggingface/modules/transformers_modules/ai4bharat/indictrans2-indic-en-1B/ac3daf0ecd37be3b6957764a9179ab2b07fa9d6a/modeling_indictrans.py in forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1359         # past_key_values_length
#    1360         past_key_values_length = (
# -> 1361             past_key_values[0][0].shape[2] if past_key_values is not None else 0
#    1362         )
#    1363
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
print(f"\n{src_lang} - {tgt_lang}")
for input_sentence, translation in zip(hi_sents, en_translations):
    print(f"{src_lang}: {input_sentence}")
    print(f"{tgt_lang}: {translation}")

# %%
# ---------------------------------------------------------------------------
#                              English to Hindi
# ---------------------------------------------------------------------------
en_sents = [
    "When I was young, I used to go to the park every day.",
    "He has many old books, which he inherited from his ancestors.",
    "I can't figure out how to solve my problem.",
    "She is very hardworking and intelligent, which is why she got all the good marks.",
    "We watched a new movie last week, which was very inspiring.",
    "If you had met me at that time, we would have gone out to eat.",
    "She went to the market with her sister to buy a new sari.",
    "Raj told me that he is going to his grandmother's house next month.",
    "All the kids were having fun at the party and were eating lots of sweets.",
    "My friend has invited me to his birthday party, and I will give him a gift.",
]
src_lang, tgt_lang = "eng_Latn", "hin_Deva"
hi_translations = batch_translate(
    en_sents, src_lang, tgt_lang, en_indic_model, en_indic_tokenizer, ip
)

print(f"\n{src_lang} - {tgt_lang}")
for input_sentence, translation in zip(en_sents, hi_translations):
    print(f"{src_lang}: {input_sentence}")
    print(f"{tgt_lang}: {translation}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-939141555.py in <cell line: 0>()
#      15 ]
#      16 src_lang, tgt_lang = "eng_Latn", "hin_Deva"
# ---> 17 hi_translations = batch_translate(
#      18     en_sents, src_lang, tgt_lang, en_indic_model, en_indic_tokenizer, ip
#      19 )
#
# /tmp/ipython-input-1932986653.py in batch_translate(input_sentences, src_lang, tgt_lang, model, tokenizer, ip)
#      18         # Generate translations using the model
#      19         with torch.no_grad():
# ---> 20             generated_tokens = model.generate(
#      21                 **inputs,
#      22                 use_cache=True,
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
#     122     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2549         elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2550             # 11. run beam sample
# -> 2551             result = self._beam_search(
#    2552                 input_ids,
#    2553                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in _beam_search(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, **model_kwargs)
#    3348             model_inputs.update({"output_hidden_states": output_hidden_states} if output_hidden_states else {})
#    3349
# -> 3350             model_outputs = self(**model_inputs, return_dict=True)
#    3351
#    3352             # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# ~/.cache/huggingface/modules/transformers_modules/ai4bharat/indictrans2-en-indic-1B/10e65a9951a1e922cd109a95e8aba9357b62144b/modeling_indictrans.py in forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1715                 )
#    1716
# -> 1717         outputs = self.model(
#    1718             input_ids,
#    1719             attention_mask=attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# ~/.cache/huggingface/modules/transformers_modules/ai4bharat/indictrans2-en-indic-1B/10e65a9951a1e922cd109a95e8aba9357b62144b/modeling_indictrans.py in forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1612
#    1613         # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_attn)
# -> 1614         decoder_outputs = self.decoder(
#    1615             input_ids=decoder_input_ids,
#    1616             attention_mask=decoder_attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# ~/.cache/huggingface/modules/transformers_modules/ai4bharat/indictrans2-en-indic-1B/10e65a9951a1e922cd109a95e8aba9357b62144b/modeling_indictrans.py in forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1359         # past_key_values_length
#    1360         past_key_values_length = (
# -> 1361             past_key_values[0][0].shape[2] if past_key_values is not None else 0
#    1362         )
#    1363
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
# ---------------------------------------------------------------------------
#                             Paragraph translation
# ---------------------------------------------------------------------------
src_lang, tgt_lang = "hin_Deva", "eng_Latn"
hi_text = "यहाँ एक पाराग्राफ है जो हिंदी में लिखा गया है। हिंदी एक सुंदर भाषा है और भारत की राष्ट्रीय भाषा है। इसका विकास विभिन्न कालों में हुआ है और यह विशेषतः भारतीय उपमहाद्वीप में बोली जाती है। हिंदी भाषा का साहित्य, संस्कृति और इतिहास भी बहुत गर्वनीय है।"
en_translated_text = translate_paragraph(
    hi_text, src_lang, tgt_lang, indic_en_model, indic_en_tokenizer, ip
)
print(f"{src_lang}: {hi_text}")
print(f"{tgt_lang}: {en_translated_text}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1492749286.py in <cell line: 0>()
#       4 src_lang, tgt_lang = "hin_Deva", "eng_Latn"
#       5 hi_text = "यहाँ एक पाराग्राफ है जो हिंदी में लिखा गया है। हिंदी एक सुंदर भाषा है और भारत की राष्ट्रीय भाषा है। इसका विकास विभिन्न कालों में हुआ है और यह विशेषतः भारतीय उपमहाद्वीप में बोली जाती है। हिंदी भाषा का साहित्य, संस्कृति और इतिहास भी बहुत गर्वनीय है।"
# ----> 6 en_translated_text = translate_paragraph(
#       7     hi_text, src_lang, tgt_lang, indic_en_model, indic_en_tokenizer, ip
#       8 )
#
# /tmp/ipython-input-4140401222.py in translate_paragraph(input_text, src_lang, tgt_lang, model, tokenizer, ip)
#       1 def translate_paragraph(input_text, src_lang, tgt_lang, model, tokenizer, ip):
#       2     input_sentences = split_sentences(input_text, src_lang)
# ----> 3     translated_text = batch_translate(input_sentences, src_lang, tgt_lang, model, tokenizer, ip)
#       4     return " ".join(translated_text)
#       5
#
# /tmp/ipython-input-1932986653.py in batch_translate(input_sentences, src_lang, tgt_lang, model, tokenizer, ip)
#      18         # Generate translations using the model
#      19         with torch.no_grad():
# ---> 20             generated_tokens = model.generate(
#      21                 **inputs,
#      22                 use_cache=True,
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
#     122     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2549         elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2550             # 11. run beam sample
# -> 2551             result = self._beam_search(
#    2552                 input_ids,
#    2553                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in _beam_search(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, **model_kwargs)
#    3348             model_inputs.update({"output_hidden_states": output_hidden_states} if output_hidden_states else {})
#    3349
# -> 3350             model_outputs = self(**model_inputs, return_dict=True)
#    3351
#    3352             # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# ~/.cache/huggingface/modules/transformers_modules/ai4bharat/indictrans2-indic-en-1B/ac3daf0ecd37be3b6957764a9179ab2b07fa9d6a/modeling_indictrans.py in forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1716                 )
#    1717
# -> 1718         outputs = self.model(
#    1719             input_ids,
#    1720             attention_mask=attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# ~/.cache/huggingface/modules/transformers_modules/ai4bharat/indictrans2-indic-en-1B/ac3daf0ecd37be3b6957764a9179ab2b07fa9d6a/modeling_indictrans.py in forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1612
#    1613         # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_attn)
# -> 1614         decoder_outputs = self.decoder(
#    1615             input_ids=decoder_input_ids,
#    1616             attention_mask=decoder_attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# ~/.cache/huggingface/modules/transformers_modules/ai4bharat/indictrans2-indic-en-1B/ac3daf0ecd37be3b6957764a9179ab2b07fa9d6a/modeling_indictrans.py in forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1359         # past_key_values_length
#    1360         past_key_values_length = (
# -> 1361             past_key_values[0][0].shape[2] if past_key_values is not None else 0
#    1362         )
#    1363
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %% [markdown]
# ## Try using git--

# %%
# !git clone https://github.com/VarunGumma/IndicTransToolkit
# %cd IndicTransToolkit
# Out:
# Cloning into 'IndicTransToolkit'...
# remote: Enumerating objects: 276, done.
# remote: Counting objects: 100% (121/121), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 276 (delta 82), reused 67 (delta 58), pack-reused 155 (from 1)
# Receiving objects: 100% (276/276), 4.39 MiB | 18.00 MiB/s, done.
# Resolving deltas: 100% (121/121), done.
# /content/IndicTransToolkit

# %%
# !pip install --editable . --use-pep517 # required for pip >= 25.0

# in case it fails, try:
# pip install --editable . --use-pep517 --config-settings editable_mode=compat
# Out:
# Obtaining file:///content/IndicTransToolkit
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: cython in /usr/local/lib/python3.12/dist-packages (from indictranstoolkit==1.1.1) (3.0.12)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.12/dist-packages (from indictranstoolkit==1.1.1) (0.1.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from indictranstoolkit==1.1.1) (4.56.1)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.12/dist-packages (from indictranstoolkit==1.1.1) (2.5.1)
# Requirement already satisfied: indic-nlp-library-itt in /usr/local/lib/python3.12/dist-packages (from indictranstoolkit==1.1.1) (0.1.1)
# Requirement already satisfied: morfessor in /usr/local/lib/python3.12/dist-packages (from indic-nlp-library-itt->indictranstoolkit==1.1.1) (2.0.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from indic-nlp-library-itt->indictranstoolkit==1.1.1) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from indic-nlp-library-itt->indictranstoolkit==1.1.1) (2.2.2)
# Requirement already satisfied: sphinx-argparse in /usr/local/lib/python3.12/dist-packages (from indic-nlp-library-itt->indictranstoolkit==1.1.1) (0.5.2)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.12/dist-packages (from indic-nlp-library-itt->indictranstoolkit==1.1.1) (3.0.2)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.12/dist-packages (from sacrebleu->indictranstoolkit==1.1.1) (3.2.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from sacrebleu->indictranstoolkit==1.1.1) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.12/dist-packages (from sacrebleu->indictranstoolkit==1.1.1) (0.9.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.12/dist-packages (from sacrebleu->indictranstoolkit==1.1.1) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from sacrebleu->indictranstoolkit==1.1.1) (5.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from sacremoses->indictranstoolkit==1.1.1) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from sacremoses->indictranstoolkit==1.1.1) (1.5.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from sacremoses->indictranstoolkit==1.1.1) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers->indictranstoolkit==1.1.1) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers->indictranstoolkit==1.1.1) (0.35.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers->indictranstoolkit==1.1.1) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers->indictranstoolkit==1.1.1) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers->indictranstoolkit==1.1.1) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->indictranstoolkit==1.1.1) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers->indictranstoolkit==1.1.1) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers->indictranstoolkit==1.1.1) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers->indictranstoolkit==1.1.1) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers->indictranstoolkit==1.1.1) (1.1.10)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->indic-nlp-library-itt->indictranstoolkit==1.1.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->indic-nlp-library-itt->indictranstoolkit==1.1.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->indic-nlp-library-itt->indictranstoolkit==1.1.1) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->indictranstoolkit==1.1.1) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->indictranstoolkit==1.1.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->indictranstoolkit==1.1.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->indictranstoolkit==1.1.1) (2025.8.3)
# Requirement already satisfied: sphinx>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from sphinx-argparse->indic-nlp-library-itt->indictranstoolkit==1.1.1) (8.2.3)
# Requirement already satisfied: docutils>=0.19 in /usr/local/lib/python3.12/dist-packages (from sphinx-argparse->indic-nlp-library-itt->indictranstoolkit==1.1.1) (0.21.2)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in /usr/local/lib/python3.12/dist-packages (from sphinx-rtd-theme->indic-nlp-library-itt->indictranstoolkit==1.1.1) (4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->indic-nlp-library-itt->indictranstoolkit==1.1.1) (1.17.0)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->indictranstoolkit==1.1.1) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->indictranstoolkit==1.1.1) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->indictranstoolkit==1.1.1) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->indictranstoolkit==1.1.1) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->indictranstoolkit==1.1.1) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->indictranstoolkit==1.1.1) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->indictranstoolkit==1.1.1) (3.1.6)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->indictranstoolkit==1.1.1) (2.19.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->indictranstoolkit==1.1.1) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->indictranstoolkit==1.1.1) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->indictranstoolkit==1.1.1) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->indictranstoolkit==1.1.1) (1.4.1)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->indictranstoolkit==1.1.1) (3.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from Jinja2>=3.1->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-itt->indictranstoolkit==1.1.1) (3.0.2)
# Building wheels for collected packages: indictranstoolkit
#   Building editable for indictranstoolkit (pyproject.toml) ... done
#   Created wheel for indictranstoolkit: filename=indictranstoolkit-1.1.1-0.editable-cp312-cp312-linux_x86_64.whl size=6504 sha256=daab078ffd0cf69c1a748f5d45242d1c01304027d2b8156729dc0ee49405cefd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9hxqd8a4/wheels/8d/e6/25/6ea361997c94ff0c53de3e9b41c28a420cc27ed22b0cf12520
# Successfully built indictranstoolkit
# Installing collected packages: indictranstoolkit
#   Attempting uninstall: indictranstoolkit
#     Found existing installation: indictranstoolkit 1.1.1
#     Uninstalling indictranstoolkit-1.1.1:
#       Successfully uninstalled indictranstoolkit-1.1.1
# Successfully installed indictranstoolkit-1.1.1

# %%
import torch
from IndicTransToolkit.processor import IndicProcessor # NOW IMPLEMENTED IN CYTHON !!
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

# %%
ip = IndicProcessor(inference=True)
tokenizer = AutoTokenizer.from_pretrained("ai4bharat/indictrans2-en-indic-dist-200M", trust_remote_code=True)
model = AutoModelForSeq2SeqLM.from_pretrained("ai4bharat/indictrans2-en-indic-dist-200M", trust_remote_code=True)

sentences = [
    "This is a test sentence.",
    "This is another longer different test sentence.",
    "Please send an SMS to 9876543210 and an email on newemail123@xyz.com by 15th October, 2023.",
]
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenization_indictrans.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-en-indic-dist-200M:
# - tokenization_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# dict.SRC.json: 0.00B [00:00, ?B/s]
# dict.TGT.json: 0.00B [00:00, ?B/s]
# model.SRC:   0%|          | 0.00/759k [00:00<?, ?B/s]
# model.TGT:   0%|          | 0.00/3.26M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/96.0 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# configuration_indictrans.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-en-indic-dist-200M:
# - configuration_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_indictrans.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-en-indic-dist-200M:
# - modeling_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors:   0%|          | 0.00/1.10G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/163 [00:00<?, ?B/s]

# %%
batch = ip.preprocess_batch(sentences, src_lang="eng_Latn", tgt_lang="hin_Deva", visualize=False) # set it to visualize=True to print a progress bar
batch = tokenizer(batch, padding="longest", truncation=True, max_length=256, return_tensors="pt")

with torch.inference_mode():
    outputs = model.generate(**batch, num_beams=5, num_return_sequences=1, max_length=256)

with tokenizer.as_target_tokenizer():
    # This scoping is absolutely necessary, as it will instruct the tokenizer to tokenize using the target vocabulary.
    # Failure to use this scoping will result in gibberish/unexpected predictions as the output will be de-tokenized with the source vocabulary instead.
    outputs = tokenizer.batch_decode(outputs, skip_special_tokens=True, clean_up_tokenization_spaces=True)

outputs = ip.postprocess_batch(outputs, lang="hin_Deva")
print(outputs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3483850902.py in <cell line: 0>()
#       3
#       4 with torch.inference_mode():
# ----> 5     outputs = model.generate(**batch, num_beams=5, num_return_sequences=1, max_length=256)
#       6
#       7 with tokenizer.as_target_tokenizer():
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
#     122     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2549         elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2550             # 11. run beam sample
# -> 2551             result = self._beam_search(
#    2552                 input_ids,
#    2553                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in _beam_search(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, **model_kwargs)
#    3348             model_inputs.update({"output_hidden_states": output_hidden_states} if output_hidden_states else {})
#    3349
# -> 3350             model_outputs = self(**model_inputs, return_dict=True)
#    3351
#    3352             # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# ~/.cache/huggingface/modules/transformers_modules/ai4bharat/indictrans2-en-indic-dist-200M/173b94239f7c38886b2747b8d4a5db771a7e1232/modeling_indictrans.py in forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1716                 )
#    1717
# -> 1718         outputs = self.model(
#    1719             input_ids,
#    1720             attention_mask=attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# ~/.cache/huggingface/modules/transformers_modules/ai4bharat/indictrans2-en-indic-dist-200M/173b94239f7c38886b2747b8d4a5db771a7e1232/modeling_indictrans.py in forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1612
#    1613         # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_attn)
# -> 1614         decoder_outputs = self.decoder(
#    1615             input_ids=decoder_input_ids,
#    1616             attention_mask=decoder_attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# ~/.cache/huggingface/modules/transformers_modules/ai4bharat/indictrans2-en-indic-dist-200M/173b94239f7c38886b2747b8d4a5db771a7e1232/modeling_indictrans.py in forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1359         # past_key_values_length
#    1360         past_key_values_length = (
# -> 1361             past_key_values[0][0].shape[2] if past_key_values is not None else 0
#    1362         )
#    1363
#
# AttributeError: 'NoneType' object has no attribute 'shape'
